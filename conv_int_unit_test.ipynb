# %%
import cymetric as cym
from cymetric import convenient_interface as com
import os
import pandas as pd
from pandas.util.testing import assert_frame_equal
import numpy as np
from uuid import UUID
from cymetric.tools import raw_to_series, ensure_dt_bytes
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
cymetric_path = '/Users/mouginot/work/app/cyclus/cymetric'
example_path = cymetric_path + '/tests/test.sqlite'

# %%
db = cym.dbopen(example_path)

# %%
myEval = cym.Evaluator(db)

# %%
myEval.eval('AgentEntry')['Prototype'].tolist()
# Out:
# ['SingleRegion',
#  'SingleInstitution',
#  'UOX_Source',
#  'MOX_Source',
#  'Reactor1',
#  'Reactor2',
#  'Reactor3']

# %%
com.get_transaction_df(myEval)
# Out:
#                                   SimId  ReceiverId ReceiverProto  SenderId  \
# 0  4d33459f-e366-4450-a796-483669702de8          15      Reactor1        13
# 1  4d33459f-e366-4450-a796-483669702de8          15      Reactor1        14
# 2  4d33459f-e366-4450-a796-483669702de8          15      Reactor1        14
# 3  4d33459f-e366-4450-a796-483669702de8          15      Reactor1        14
# 4  4d33459f-e366-4450-a796-483669702de8          16      Reactor2        14
# 5  4d33459f-e366-4450-a796-483669702de8          16      Reactor2        14
# 6  4d33459f-e366-4450-a796-483669702de8          16      Reactor2        14
# 7  4d33459f-e366-4450-a796-483669702de8          17      Reactor3        13
# 8  4d33459f-e366-4450-a796-483669702de8          17      Reactor3        14
#
#   SenderProto  TransactionId  ResourceId Commodity  Time
# 0  UOX_Source              6          74       uox     4
# 1  MOX_Source              0           8       mox     1
# 2  MOX_Source              1          23       mox     2
# 3  MOX_Source              4          49       mox     3
# 4  MOX_Source              2          25       mox     2
# 5  MOX_Source              5          51       mox     3
# 6  MOX_Source              7          76       mox     4
# 7  UOX_Source              3          47       uox     3
# 8  MOX_Source              8          78       mox     4

# %%
com.get_flow_graph(myEval)

# %%
com.get_flow_graph(myEval, time=[3,5])

# %%
com.get_flow_graph(myEval, time=[-1,3])
