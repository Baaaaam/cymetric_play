# %%
import cymetric as cym
import os
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
cymetric_path = 'home/mouginot/work/app/cyclus/cymetric'
example_path = cymetric_path + '/tests/test.sqlite'

# %%
# Open the database
db = cym.dbopen("cyclus.sqlite")

# %%
# Define an Evaluator, allows to acces the different data tables in the database
myEval = cym.Evaluator(db, write=False)

# %%
myEval.eval('Resources', normed=False)
# Out:
#                                      SimId  ResourceId  ObjId      Type  \
# 0     5bfd2817-8634-4e6e-a969-cc4105acc35d          21     20  Material
# 1     5bfd2817-8634-4e6e-a969-cc4105acc35d          23     21  Material
# 2     5bfd2817-8634-4e6e-a969-cc4105acc35d          39     20  Material
# 3     5bfd2817-8634-4e6e-a969-cc4105acc35d          43     21  Material
# 4     5bfd2817-8634-4e6e-a969-cc4105acc35d          46     41  Material
# ...                                    ...         ...    ...       ...
# 2574  5bfd2817-8634-4e6e-a969-cc4105acc35d       20132  17504  Material
# 2575  5bfd2817-8634-4e6e-a969-cc4105acc35d       20133  17327  Material
# 2576  5bfd2817-8634-4e6e-a969-cc4105acc35d       20146     20  Material
# 2577  5bfd2817-8634-4e6e-a969-cc4105acc35d       20149     20  Material
# 2578  5bfd2817-8634-4e6e-a969-cc4105acc35d       20150  17571  Material
#
#       TimeCreated        Quantity Units  QualId  Parent1  Parent2
# ...

# %%
# Acces on specific table (here Materials)
myEval.eval('Resources', normed=True)
# Out:
#                                      SimId  ResourceId  ObjId      Type  \
# 0     5bfd2817-8634-4e6e-a969-cc4105acc35d          21     20  Material
# 1     5bfd2817-8634-4e6e-a969-cc4105acc35d          23     21  Material
# 2     5bfd2817-8634-4e6e-a969-cc4105acc35d          39     20  Material
# 3     5bfd2817-8634-4e6e-a969-cc4105acc35d          43     21  Material
# 4     5bfd2817-8634-4e6e-a969-cc4105acc35d          46     41  Material
# ...                                    ...         ...    ...       ...
# 2574  5bfd2817-8634-4e6e-a969-cc4105acc35d       20132  17504  Material
# 2575  5bfd2817-8634-4e6e-a969-cc4105acc35d       20133  17327  Material
# 2576  5bfd2817-8634-4e6e-a969-cc4105acc35d       20146     20  Material
# 2577  5bfd2817-8634-4e6e-a969-cc4105acc35d       20149     20  Material
# 2578  5bfd2817-8634-4e6e-a969-cc4105acc35d       20150  17571  Material
#
#       TimeCreated  Quantity [g]  QualId  Parent1  Parent2
# ...

# %%
myEval.eval('Materials', normed=True)

# %%
y

# %%
y.name = "test"

# %%
tt = y.reset_index()
tt
