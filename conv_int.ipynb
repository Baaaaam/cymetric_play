# %%
import cymetric as cym
import os
import pandas as pd
# Out:
# {'Mass': ['Units', 'kg', '']}
# [('SimId', 7, None), ('QualId', 1, None), ('ResourceId', 1, None), ('ObjId', 1, None), ('TimeCreated', 1, None), ('NucId', 1, None), ('Units', 4, None), ('Mass', 3, None)]
# [('SimId', 7, None), ('QualId', 1, None), ('ResourceId', 1, None), ('ObjId', 1, None), ('TimeCreated', 1, None), ('NucId', 1, None), ('Mass', 3, None)]
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
cymetric_path = 'home/mouginot/work/app/cyclus/cymetric'
example_path = cymetric_path + '/tests/test.sqlite'

# %%
# Open the database
db = cym.dbopen("cyclus.sqlite")

# %%
# Define an Evaluator, allows to acces the different data tables in the database
myEval = cym.Evaluator(db, write=False)

# %%
# Acces on specific table (here Materials)
myEval.eval('norm_Materials')
# Out:
# defunit  gram
#                                        SimId  QualId  ResourceId  ObjId  \
# 0       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 1       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 2       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 3       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 4       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# ...                                      ...     ...         ...    ...
# 211200  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211201  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211202  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211203  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211204  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
#
#         TimeCreated      NucId       Mass [g]
# 0                 1  922340000   2.000120e+04
# 1                 1  922350000   2.030122e+06
# 2                 1  922360000   8.300498e+05
# 3                 1  922370000   0.000000e+00
# 4                 1  922380000   8.108687e+08
# ...             ...        ...            ...
# 211200         1482  942420000   1.509322e+05
# 211201         1482  942430000  5.426643e-188
# 211202         1482  942440000   7.004819e+00
# 211203         1482  952410000   3.377577e+03
# 211204         1482  952430000   1.664916e-10
#
# [211205 rows x 7 columns]

# %%
myEval.eval('Materials')
# Out:
#                                        SimId  QualId  ResourceId  ObjId  \
# 0       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 1       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 2       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 3       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# 4       5bfd2817-8634-4e6e-a969-cc4105acc35d       5          21     20
# ...                                      ...     ...         ...    ...
# 211200  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211201  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211202  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211203  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
# 211204  5bfd2817-8634-4e6e-a969-cc4105acc35d  231314       20133  17327
#
#         TimeCreated      NucId Units           Mass
# 0                 1  922340000    kg   2.000120e+01
# 1                 1  922350000    kg   2.030122e+03
# 2                 1  922360000    kg   8.300498e+02
# 3                 1  922370000    kg   0.000000e+00
# 4                 1  922380000    kg   8.108687e+05
# ...             ...        ...   ...            ...
# 211200         1482  942420000    kg   1.509322e+02
# 211201         1482  942430000    kg  5.426643e-191
# 211202         1482  942440000    kg   7.004819e-03
# 211203         1482  952410000    kg   3.377577e+00
# 211204         1482  952430000    kg   1.664916e-13
#
# [211205 rows x 8 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc2738d3df36> in <module>
#       1 # Request a Panda Data Frame containing the activities of all the transactions from only 239Pu and 238U
# ----> 2 cal = com.get_transaction_activity_df(myEval, nuc_list=['942390000', '922380000'])
#       3 cal
#
# NameError: name 'com' is not defined
