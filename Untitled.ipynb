# %%
from cymetric import convenient_interface as com
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
import cymetric as cym

# %%
#load db in a evaler
db = cym.dbopen('cyclus.sqlite')

# %%
plot1 = com.get_transaction_timeseries(db, 'PWR_separation', 'J1_second_storage', ['pu239'])

# %%
plot1 = com.get_inventory_timeseries(db, 'PWR_storage', ['pu239'])

# %%
plot1
# Out:
#       Prototype  Time   Quantity
# 0   PWR_storage   108  758.73916
# 1   PWR_storage   126  758.73916
# 2   PWR_storage   144  758.73916
# 3   PWR_storage   162  758.73916
# 4   PWR_storage   180  758.73916
# 5   PWR_storage   198  758.73916
# 6   PWR_storage   216  758.73916
# 7   PWR_storage   234  758.73916
# 8   PWR_storage   252  758.73916
# 9   PWR_storage   270  758.73916
# 10  PWR_storage   288  758.73916
# 11  PWR_storage   306  758.73916
# 12  PWR_storage   324  758.73916
# 13  PWR_storage   342  758.73916
# 14  PWR_storage   360  758.73916
# 15  PWR_storage   378  758.73916
# 16  PWR_storage   396  758.73916
# 17  PWR_storage   414  758.73916
# 18  PWR_storage   432  758.73916
# 19  PWR_storage   450  758.73916
# 20  PWR_storage   468  758.73916
# 21  PWR_storage   486  758.73916
# 22  PWR_storage   504  758.73916
# 23  PWR_storage   522  758.73916
# 24  PWR_storage   540  758.73916
# 25  PWR_storage   558  758.73916
# 26  PWR_storage   576  758.73916
# ...
